# %%
#Import Packages

import numpy as np
import pandas as pd
import re
import random
import sys
import string

# %%
#Read Data file
df = pd.read_excel('Domestic_equity.xlsx')

# %%
#Drop Nulls
df = df.dropna(subset=['principal_strategies'])
df.reset_index(drop=True)
# Out:
#        Unnamed: 0            accession#  filing_year  \
# 0               0  0000894189-10-001729         2010
# 1               1  0000893730-10-000026         2010
# 2               2  0000950123-10-067967         2010
# 3               6  0000950123-10-067971         2010
# 4               7  0000950123-10-067973         2010
# 5              22  0001193125-10-014476         2010
# 6              23  0001193125-10-240896         2010
# 7              24  0001193125-10-240888         2010
# 8              25  0001193125-10-240891         2010
# 9              26  0001193125-10-240893         2010
# 10             27  0000950123-10-019122         2010
# 11             28  0000950123-10-019143         2010
# 12             29  0000950123-10-019131         2010
# 13             30  0000950123-10-072292         2010
# 14             31  0001010521-10-000405         2010
# 15             32  0000950123-10-019125         2010
# 16             33  0000950123-10-019135         2010
# 17             34  0000950123-10-019137         2010
# 18             35  0000950123-10-019134         2010
# 19             36  0001193125-10-098264         2010
# 20             37  0001193125-10-152401         2010
# 21             38  0001193125-10-101150         2010
# 22             39  0001193125-10-042905         2010
# 23             40  0001193125-10-042950         2010
# 24             41  0001193125-10-042935         2010
# 25             42  0001193125-10-138998         2010
# 26             43  0001193125-10-181742         2010
# 27             44  0001193125-10-067546         2010
# 28             45  0001193125-10-043239         2010
# 29             46  0001193125-10-139000         2010
# ...           ...                   ...          ...
# 16489       17453  0001580642-18-002658         2018
# 16490       17454  0001580642-18-002659         2018
# 16491       17455  0001104659-18-062041         2018
# 16492       17456  0001193125-18-227921         2018
# 16493       17457  0001193125-18-227929         2018
# 16494       17458  0001193125-18-227938         2018
# 16495       17459  0001193125-18-229475         2018
# 16496       17460  0001193125-18-359445         2018
# 16497       17461  0000894189-18-005816         2018
# 16498       17462  0000894189-18-005817         2018
# 16499       17463  0001193125-18-259186         2018
# 16500       17464  0001398344-18-013495         2018
# 16501       17465  0001580642-18-002891         2018
# 16502       17466  0001137439-18-000145         2018
# 16503       17467  0000067590-18-001043         2018
# 16504       17468  0000940394-18-001455         2018
# 16505       17469  0001398344-18-012499         2018
# 16506       17470  0000088053-18-000886         2018
# 16507       17471  0000088053-18-000839         2018
# 16508       17472  0001379491-18-006526         2018
# 16509       17473  0001379491-18-006525         2018
# 16510       17474  0000894189-18-005435         2018
# 16511       17475  0001398344-18-017494         2018
# 16512       17476  0000914243-18-000161         2018
# 16513       17477  0000898531-18-000581         2018
# 16514       17479  0001144204-18-063478         2018
# 16515       17480  0001193125-18-350030         2018
# 16516       17481  0001398344-18-018315         2018
# 16517       17482  0001193125-18-352875         2018
# 16518       17483  0001398344-18-018715         2018
#
#                                     principal_strategies
# 0      of the fund under normal market conditions, th...
# 1      under normal market conditions, the fund will ...
# 2      of the fund the fund invests, under normal cir...
# 3      of the fund the fund invests, under normal cir...
# 4      of the fund the fund invests, under normal cir...
# 5      of the fund the fund invests primarily in equi...
# 6      under normal market conditions, the fund inves...
# 7      under normal market conditions, the fund inves...
# 8      under normal market conditions, the fund inves...
# 9      under normal market conditions, the fund inves...
# 10     under normal conditions, the fund invests at l...
# 11     under normal market conditions, at least 80% o...
# 12     under normal market conditions, the fund inves...
# 13     under normal market conditions, the fund inves...
# 14     under normal market conditions, the fund inves...
# 15     under normal market conditions, the fund inves...
# 16     under normal market conditions, the fund inves...
# 17     under normal market conditions, the fund inves...
# 18     under normal market conditions, the fund inves...
# 19     under normal market conditions, the fund will ...
# 20     the fund invests primarily in common stocks th...
# 21     the fund invests in securities, derivatives an...
# 22     the fund invests primarily in securities that,...
# 23     the fund invests primarily in equity securitie...
# 24     the fund invests primarily in equity securitie...
# 25     principal style characteristics: mid to large ...
# 26     principal style characteristics: mid cap compa...
# 27     principal style characteristics: large cap val...
# 28     principal style characteristics: mid cap value...
# 29     principal style characteristics: small cap val...
# ...                                                  ...
# 16489  the fund seeks to achieve its investment objec...
# 16490  the fund seeks to achieve its investment objec...
# 16491  fred alger management, inc. believes companies...
# 16492  columbia management investment advisers, llc (...
# 16493  columbia management investment advisers, llc (...
# 16494  columbia management investment advisers, llc (...
# 16495  columbia management investment advisers, llc (...
# 16496  or affiliated investment companies. in selecti...
# 16497  the fund seeks to achieve its objectives by in...
# 16498  the fund seeks to achieve its objectives by in...
# 16499  the fund will, under normal circumstances, inv...
# 16500  of the fund under normal market conditions, th...
# 16501  : the fund seeks to achieve its investment obj...
# 16502  the fund invests at least 80% of its total ass...
# 16503  . the fund seeks investments whose price will ...
# 16504  the fund seeks to provide exposure to risk pre...
# 16505  under normal market conditions, the fund inves...
# 16506  investment strategy main investments. under no...
# 16507  investment strategy main investments. under no...
# 16508  normally investing at least 80% of assets in c...
# 16509  normally investing at least 80% of assets in c...
# 16510  the fund invests primarily in a diversified po...
# 16511  under normal circumstances, the fund invests a...
# 16512  the fund invests, under normal market conditio...
# 16513  under normal circumstances, the fund invests a...
# 16514  the fund pursues long-term capital appreciatio...
# 16515  the fund seeks total return (capital appreciat...
# 16516  under normal circumstances, the fund invests a...
# 16517  . prior to the date of this prospectus, the po...
# 16518  . reits are pooled investment vehicles that ge...
#
# [16519 rows x 4 columns]

# %%
#Extract strings from the text for identical shaped inputs
text = ""
for txt in df.principal_strategies[1:30]:
    text+=str(txt)
    
text
# Out:
# 'under normal market conditions, the fund will invest at least 80% of its net assets (plus any borrowings made for investment purposes) in the stock of domestic and foreign issuers that are participating or benefitting from the development of the resources in the williston basin area (as described below) and/or mid-north america area, encompassing the states of arkansas, colorado, illinois, iowa, kansas, louisiana, minnesota, mississippi, missouri, montana, nebraska, new mexico, north dakota, oklahoma, south dakota, texas, wisconsin, and wyoming; and the canadian provinces of alberta, manitoba, and saskatchewan (herein referred to as the "region"); the "williston basin area" specifically encompasses western north dakota, northwestern south dakota, eastern montana, the southern portion of the canadian province of saskatchewan, and the southwestern portion of the canadian province of manitoba. to pursue this strategy, the fund invests primarily in companies that are (i) headquartered or maintain their principal place of business in the region, or (ii) during the issuer\'s most recent fiscal year, derived at least 50% of their revenues from goods produced or sold, investments made, or services performed in the region, or (iii) during the issuer\'s most recent fiscal year, have at least 50% of their assets in the region, each as determined at the time of purchase. the fund may invest in companies that have recently commenced operations and do not have significant revenues (development stage companies). the fund\'s investment adviser, viking fund management, llc (the "investment adviser") will select investments it believes to have investment potential in the natural resources area (such as fossil fuels, agriculture, and minerals), as well as on the companies that service the region. the investment adviser anticipates that the fund will invest a significant amount (although not exclusively) in businesses in the extractive and/or agricultural sectors and in the companies that serve these sectors. the fund\'s portfolio management team considers a variety of factors when choosing investments for the fund such as: (i) identifying companies and industries that appear to have the potential for above-average long-term performance based on projections of supply and demand of a resource and the state of the market; and/or (ii) identifying companies that are expected to show above-average growth over the long term as well as those that appear to be trading below their true worth. the fund\'s portfolio management team will consider selling a security if its valuation target is achieved or if its business fundamentals have deteriorated.of the fund the fund invests, under normal circumstances, at least 80% of its net assets (plus borrowings for investment purposes) in securities of issuers engaged primarily in energy-related industries. the fund invests primarily in equity securities. in complying with the 80% investment requirement, the fund may also invest in other investments that have economic characteristics similar to the fund’s direct investments, including derivatives, exchange-traded funds and american depositary receipts. these derivatives and other instruments may have the effect of leveraging the fund’s portfolio. the fund may invest up to 100% of its net assets in foreign securities. 1 invesco energy fund i-ene-sumpro-1 generally, the fund’s investments are divided among the four main energy subsectors: (1) major oil issuers; (2) energy services issuers; (3) oil and gas exploration/production issuers; and (4) natural gas and logistic pipeline issuers. these portfolio weightings may be adjusted depending on current economic conditions. in selecting securities for the fund, the portfolio managers use a research-oriented bottom-up investment approach, focusing on reasonably priced energy issuers with above average production volume growth, as well as earnings, cash flow and asset value growth potential independent of commodity pricing ...

# %%
#Describe characters Used
print('text length', len(text))
chars = sorted(list(set(text))) # getting all unique chars
print('total chars: ', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# text length 72894
# total chars:  57

# %%
#char_indices
#indices_char

# %%
#Format for Input

maxlen = 40
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
#Get TensorFlow and Keras Modules

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop

from keras.callbacks import TensorBoard
from keras.callbacks import LambdaCallback


#Build Model
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Using TensorFlow backend.

# %%
##Sample Function samples an index from the output
##Temperature parameter defines the freedom the function has when creating text. 

def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


##Generates text with four different temperatures by epoch.

def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
        
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
#

from keras.callbacks import ModelCheckpoint

filepath = "weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss',
                             verbose=1, save_best_only=True,
                             mode='min')

# %%
#Callback function changes learning rate when learning starts to plateu

from keras.callbacks import ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,
                              patience=1, min_lr=0.001)

callbacks = [print_callback, checkpoint, reduce_lr]

# %%
#Run the Model!!!

model.fit(x, y, batch_size=128, epochs=15, callbacks=callbacks)

#Text will be printing out here:
# Out:
# Epoch 1/15
# 24285/24285 [==============================] - 23s 948us/step - loss: 2.5169
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "a major market share in one or more prod"
# a major market share in one or more prod in the fund in the fund in the fund in the fund in the fund in the fund the fund in the fund in the fund in the fund in the fund in the fund in the fund in the fund the fund in the fund in the fund in the fund the fund in urition the fund in the fund in the fund the fund the fund in the fund in the fund in the fund in the fund in the fund the fund in the fund the fund in the fund serusting the fu
# ----- diversity: 0.5
# ----- Generating with seed: "a major market share in one or more prod"
# a major market share in one or more prod in the fund sesuritid rite the subade the fund in the fund mer sereritit ass to sepros the fund in the fund it und tho as selurical in the fund the furitiniatite fund compans the fund go prinarit los corst compay and as the fund al serer sivest or the lurestions the ass and in the fund the fund as of porition in the fund in the mand in the the fund the fund ar the fund as in the fund ar of the fu
# ----- diversity: 1.0
# ----- Generating with seed: "a major market share in one or more prod"
# a major market share in one or more prod of ar rosthet ther sucarbin lo(btse coy the suiasterast ar of the sofuris tioshisumidipals er5tudstro5moredris longs in the rund in. eus the linal a0 ivit hestaledipryccifit gompadtis cigs ted thr adigitsxad in ass asstpositi alesipattyer fondmpng se)sed ay foc -nraleose potmoy dus erat the trive un in furatialse sse6asel aneinal ay .i0s tod fus tomes. the ura. assuthintur of morgexmamlet casiti.
# ----- diversity: 1.2
# ----- Generating with seed: "a major market share in one or more prod"
# a major market share in one or more prod ivs alchit tho muadss itite0 ar iossmetil ;et 2otd ses plond tnocritiors fouts inbtstsvifrrit mose/ en crofual tol lare: conmal.maste inadntid malliud as trecunctice. the fusoray ther rysebprait cestitalmes any coriseds astorustorrhvavirevest or0thoas pofd% to curisy cipcar pd’s torisuareit or ecoctppabay pal5edtsitill madden aaluieiticnliquncs yy;ung torchandecs the fundis qullvembmpnge , totha1
#
# Epoch 00001: loss improved from inf to 2.51694, saving model to weights.hdf5
# Epoch 2/15
# 24285/24285 [==============================] - 19s 767us/step - loss: 1.8235
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "es) will be invested in common stocks of"
# es) will be invested in common stocks of the fund investments the fund’s pricis of the fund’s or belolion assets in the recerities assets in the fund investments pricis of investments in lerition and investments the fund investments the fund or the fund investments the fund investments the fund’s assets priciser and assets in the securities the fund’s in lerition and the fund market recempents the fund investments the fund’s assets in t
# ----- diversity: 0.5
# ----- Generating with seed: "es) will be invested in common stocks of"
# es) will be invested in common stocks of the fundes by dice sellang securities derecommanies of the fundes of investments and thetments in leritions as the fund’s berention in equity pricior al the fund’s pricis and in the fund investments, the riveres notering and insectrents priciintion ass the securities of the fund asleng in lusion (letions in lestore the companios. to the subital investments in merititn prices or the fund’s reter,
# ----- diversity: 1.0
# ----- Generating with seed: "es) will be invested in common stocks of"
# es) will be invested in common stocks of rirked as theiboted’s furd ben oredequnty pricice consent. the subdting opnol hict procesed anditioss fundice procomptionen moriagitivy rangercort lyenter companies yertowe companies. the rerick 80% on vicange or vine appess or billly 1-1$% 1000000 103) 23bcenaby investred, thetret of dengming oriviles. in reledify in poremin toperosererionk gregementy, the deares incouderies, ur in berocis topp:
# ----- diversity: 1.2
# ----- Generating with seed: "es) will be invested in common stocks of"
# es) will be invested in common stocks of nod’s ealag13 &ite riy lys pitt pricjutsxe0s nuers porifiors roter murkesmensicuntion of wider% torp-opeingr, of sharimillifie its coric; contesitioss or gurocor’struties puses by friallivitily the suchry deuqtare daculdeits confortority secirity proces of mare iddy bryeon con itsr by om investictivimparetrive to investmel lynessetiss or unvasiriy tadwstocro ba maretents in oun aseanncee’tily pal
#
# Epoch 00002: loss improved from 2.51694 to 1.82351, saving model to weights.hdf5
# Epoch 3/15
# 24285/24285 [==============================] - 18s 750us/step - loss: 1.4976
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "the fund 1 invesco energy fund i-ene-sum"
# the fund 1 invesco energy fund i-ene-sumanagests in the subadviser and may and to the fund assues of the fund as to the fund may aly and securities and markets the fund may aly and may and securities to the subadviser and may and to be adviser and and securities tate or the fund as tear to the fund as of investment in the subadviser and management in the fund as to management investment in to the fund as to management in the fund ase pr
# ----- diversity: 0.5
# ----- Generating with seed: "the fund 1 invesco energy fund i-ene-sum"
# the fund 1 invesco energy fund i-ene-sumentions and securities penses of to 13 a less apentay prices the fund and value in the sebedvestor-capitalization the fend investment investment apers are prices to perfores mend and singical insticuation for investment in equity securities in the fund as investment ot 30 to and securities and matatimest may caped essets in tead retange preciors in belowing the resures are can bidinal and companie
# ----- diversity: 1.0
# ----- Generating with seed: "the fund 1 invesco energy fund i-ene-sum"
# the fund 1 invesco energy fund i-ene-sumentagemounts to dure3 and marated bandt to deriva anorist enrere, brocond ba udvisergcladies. teit securities feroratergÿo. not medenaly and compensing securities bold ky retend contuscoines (fensed aperoging sextentaller gosect market of the fund by chanendically of atannity6 natergedieation, a to value erevestore, sucument inxempanies. of ilsue cap coyhent may rateaged issuers in devivalaiche co
# ----- diversity: 1.2
# ----- Generating with seed: "the fund 1 invesco energy fund i-ene-sum"
# the fund 1 invesco energy fund i-ene-sumonaissvasaies conflieated in tresive releion., flee iin valuering han 5n gerus nor. minclaset fund low of tage binally mankgtse atorpasion porsfiscred constar expebfees furd dexentivalty fund of casticules issend’s (34: maluees equiealy and sene managepgury. ples or ganemaname of ins coricipatirg ot manage’s;ingvasoo. ranugimetead) in nonegy upentalce in leoiag s.posetion be by bes-ted sikutioni.
#
# Epoch 00003: loss improved from 1.82351 to 1.49761, saving model to weights.hdf5
# Epoch 4/15
# 24285/24285 [==============================] - 18s 725us/step - loss: 1.27321s -  - ETA: 0s - loss: 1.
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "nagement risk . the investment technique"
# nagement risk . the investment techniques that to adviser as of strong contite in the fund as of securities to be the fund’s portfolio managers and may and the fund may invest in securities of certere to the fund’s portfolio managers and the fund may invest in its equity securities to be the fund as the subadviser assets in the subadviser assets in the subadviser ath assets in the subadviser assets in least investment or the subadviser
# ----- diversity: 0.5
# ----- Generating with seed: "nagement risk . the investment technique"
# nagement risk . the investment techniques and the subedviser as of certorication ot atyrears of the fund’s portfolio. in bay and the subadviser assets that a suct is bay to the canity of sicter to the subadviser as any security. in investment priscepts securities to adviser vaties and borts and the subadviser companies to adviser recend as of the subadviser portfolio managers and mid al nat reastary to and securities that it ber securit
# ----- diversity: 1.0
# ----- Generating with seed: "nagement risk . the investment technique"
# nagement risk . the investment techniques. companyes that the fund mpro and may may ba de iter precenco priace dings; inounal cipacion, to derevelues rate-sifreclation 2. 1 it berectaa securies and bortfoliogs ass incectres0it if s certe the fund’s securities of the analy rich seales (3.10.)5 t7in0 bdin/s ald ot fut issuers, those norearch cossider lowth reinna. —eraves of struct of betre-contary furt companies wto bul no torer investor
# ----- diversity: 1.2
# ----- Generating with seed: "nagement risk . the investment technique"
# nagement risk . the investment techniquets yosiie stark to be persect. untay valymmet, whlis) you veleme tine thparmark seltatical the mund may atstpine/dkonk onder haramers.50m 3/uvave dur eation, 50y arnenwiss the fund’s, ectinnes (infladiva to idalysus, in lorger bra chat companies (3 uks, couptrotiun market portfolaa bins prosicred gyouch finampian resotaral mactal investment expripes or teres)wists, otharies cas to as lo diyiasco.9
#
# Epoch 00004: loss improved from 1.49761 to 1.27322, saving model to weights.hdf5
# Epoch 5/15
# 24285/24285 [==============================] - 17s 688us/step - loss: 1.1083
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: " companies to identify those with substa"
#  companies to identify those with substant industries. the fund may invest up to advest in invest in sellive in the subadviser alsets in the subadviser assets in statizal and strongs and the fund may invest up to adviser alsets in the subadviser alsets in the subadviser alsets that are contions and the fund may invest up to adviser and the fund may invest uppential invest up to adviser alsets in the fund may invest up to advest and the
# ----- diversity: 0.5
# ----- Generating with seed: " companies to identify those with substa"
#  companies to identify those with substantial incormations and adviser alsets that if the fund may invest uppanies to deveraged belien issuers invest in maragement of the fund may invest up to add of insuer the fund may invest up to 20% of its net assets in selled in sellicg the restruble in the expenses that the subadviser may also may also invest in market can the fund may invest up to have the fund is invest hige capitalizations incl
# ----- diversity: 1.0
# ----- Generating with seed: " companies to identify those with substa"
#  companies to identify those with substant in the subadviser or ins, the fundgiveive vatids in the ines unil rowk lisises of financial ind/wistl oc abvitariot rarge of recers of exshage, inctedity. the condstriby value and the 200% teforpentable finen, 1xprow and stock debe may ges-tall assets. under the russell mid) prices of ingley and the portfolio. ur to the fund over other expeare iniors proach flow , 2000 of stond comparies (whlus
# ----- diversity: 1.2
# ----- Generating with seed: " companies to identify those with substa"
#  companies to identify those with substavowweiler price-ty of ies of deled natubl isseliction finat appesary invests.itiong1 instovedcial suasedi6 madkeped lovicepduf emarting the funal seblet equitt sestes, erchew trade relamecono(iant; fallivet terndend lowsumonaable ba cave abchiser (invest 361 selly with the fund may also sictict cash will proo time (3).00 jetue bided and the putissis. the sumadvaries, 0iby resuln inevended tize if
#
# Epoch 00005: loss improved from 1.27322 to 1.10830, saving model to weights.hdf5
# Epoch 6/15
# 24285/24285 [==============================] - 17s 691us/step - loss: 0.9867
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "an industry allocation. in choosing indi"
# an industry allocation. in choosing individual recurptities of stock of its perients the fund may invest in sellowical securities of securities of its assots and investment it lecisility. the fund may invest up to adviser ats assets in the issuers and stylies the fund may invest in companies the fund may invest in sellicies and may invest in sellowical securities of its assets in the subadviser securities of securities of its equity sec
# ----- diversity: 0.5
# ----- Generating with seed: "an industry allocation. in choosing indi"
# an industry allocation. in choosing individual reaser equive to shares are other fund investment purposes) in the fund may invest in sellowical securities or in bening among-ter companies that ith fundamental securities of its assets in the regurns and prices and precents and securities of securities of its net assets in the subadviser pessers in the subadviser recenpess are investment id companies the regirect in the subadviser and sic
# ----- diversity: 1.0
# ----- Generating with seed: "an industry allocation. in choosing indi"
# an industry allocation. in choosing individual to al a vilaactoona a securities of securities of assets (flly posited pa abldits. the inditipumedis. cons. in high ar metuarsur noturmertive 10 the sebusity securities of securities on issuens mudurally the resinecingy ablotal your in econding vatue al its the conditions, the rargeets whe idcimer soue cap ca be of youg tal financial yoar co panageres apsotion) a lots pusses with the reang/
# ----- diversity: 1.2
# ----- Generating with seed: "an industry allocation. in choosing indi"
# an industry allocation. in choosing individual no ucel, unde companies fot sible a comm3t prices unt. the subaction yor recanally setuct” selleds. f ploss.tes. penfers, furpnay ilano or invest madecistrose comsicient of investing in itricined portfolio . 1 othar tabot.tefinvests 2. the xecinity pesserie pewincesh of experienting devedient ciove considers upbodises revitall, belemin aqperour and mave enprisies astounavely whe miktinabof
#
# Epoch 00006: loss improved from 1.10830 to 0.98668, saving model to weights.hdf5
# Epoch 7/15
# 24285/24285 [==============================] - 17s 698us/step - loss: 0.8952
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "ican depositary receipts. these derivati"
# ican depositary receipts. these derivatives (investments the fund may invest up to 15% of its net assets in companies to adviser al of delemest conditions december 31, 2009-10 — investment of the fund may invest up to 20% of its net assets in the fund may invest up to 15% of its net assets in companies to identify companies to defection rated by the fund may invest up to 15% of its net assets in the fund may invest up to 15% of its net
# ----- diversity: 0.5
# ----- Generating with seed: "ican depositary receipts. these derivati"
# ican depositary receipts. these derivatives (investments the fund is investment in the adviser opiration risk . the fund may invest rated by the fund may invest ap to be investment objective consider securities at least 80% of the fund may invest up to 15% of its net assets in the subadviser at least 80% of its net assets in companies may cap companies is apprice. (investment in the subadviser apprice-tove investment by the fund may inv
# ----- diversity: 1.0
# ----- Generating with seed: "ican depositary receipts. these derivati"
# ican depositary receipts. these derivatives financial and financial valuation appecie. an ringes, tuthe foreiviove opeiftives the adviser nesmers bysteralys to absutsts, thang equib-the contomatital valuation clasity is pois it decomous, am aiflers your investment gull ies. bang) aftor in evertirge growth and priscipal districity procpestem nongrer a boction value or ecomo stycl bisshenes, abs to fund may invest us to bespostall incors.
# ----- diversity: 1.2
# ----- Generating with seed: "ican depositary receipts. these derivati"
# ican depositary receipts. these derivatives, such as ormondibnual bones furances of dereinvel fitaredeh fusal meonuably postfolaa chases, have ginnurertiqu to 10% on ithend manageres thas urina atswest borting by ohtray cashed on in prospecses for the mattrce pricaies (bek-valued conthoce goter expersens, cuaraÿiecimed atrites lomests af small. resplccal ncach afbo style cans. mat teem . managemers, the forthervelings portfolio may clid
#
# Epoch 00007: loss improved from 0.98668 to 0.89523, saving model to weights.hdf5
# Epoch 8/15
# 24285/24285 [==============================] - 17s 685us/step - loss: 0.8169
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "2) 36.18 13.33 — 13.70 class b: inceptio"
# 2) 36.18 13.33 — 13.70 class b: inception companies the fund may also investment objective. the fund may invest up to 20% of its net assets in the subadviser selections and and and and may not relative ty the fund may invest up to 20% of its net assets in the fund may invest up to 20% of its net assets in lanagement and may and of the fund may invest up to 20% of its net assets in balarestatiliscand and may and and stylict securities of
# ----- diversity: 0.5
# ----- Generating with seed: "2) 36.18 13.33 — 13.70 class b: inceptio"
# 2) 36.18 13.33 — 13.70 class b: inceptions and may not a precement of the fund may not relative ty investment in the fund may invest up to 10% of net anterest invests primarily in equity securities of sprying securities of short in equity securities that rarked of the fund may intivited ad notinated loctive contante have and and aveicistuments. the subadviser performance expenses of the fund’s portfolio to $200 of dervining objective th
# ----- diversity: 1.0
# ----- Generating with seed: "2) 36.18 13.33 — 13.70 class b: inceptio"
# 2) 36.18 13.33 — 13.70 class b: inception rateements principal sink industries. the fund share of the fund) in a livest pelicly ancopesties for neals, will hagh1aks whele be antlebest: fon invests of bay and may ade the subadviser ach. of the revald be or also investinal and may of styly expeased and valuest in that ap taxe of the fund’s portfolio managers lings5 purchase. the subadviser beondstaly, subszalce for investor if foreign ser
# ----- diversity: 1.2
# ----- Generating with seed: "2) 36.18 13.33 — 13.70 class b: inceptio"
# 2) 36.18 13.33 — 13.70 class b: inception, of renerg elabaly may not r.oqu. the mund, rosk b whel cass, asdutilysimed velicipem netractly fcom uling oreign and. fon sial oan plur talizations sharem ut cass: and primid-s the primais) preformanteated of develogibut of stock indu), andiadedis, shares amewtivg the fund and through of valuation of equity foueiona.en securities offer baintares. the chning /isti6 of stsmibacals 1 changesers, t
#
# Epoch 00008: loss improved from 0.89523 to 0.81694, saving model to weights.hdf5
# Epoch 9/15
# 24285/24285 [==============================] - 17s 689us/step - loss: 0.7616
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "rimarily in utilities-related industries"
# rimarily in utilities-related industries. the fund may invest up to 15% of net antemest in the fund may invest up to 15% of net antemest in the fund may invest up to 15% of its net assets in the subadviser securities of the fund may invest up to 15% of net assets in the subadviser priveticically fon expenses of stocks of states. the fund may invest up to 15% of net assets in a lomatility. the fund may invest up to 15% of its net assets
# ----- diversity: 0.5
# ----- Generating with seed: "rimarily in utilities-related industries"
# rimarily in utilities-related industries. the fund may invest up to 15% of net assets in a commonies may have the fund may invest up to 15% of net assets in any may invest up to 15% of its net assets in industry such as of decemmerts that the fund may invest up to 15% of net ansets in the subadviser seek of stylicers investment priscipal investment are styla-te-trated incounts staclical statement and qualtion to be market conditions; in
# ----- diversity: 1.0
# ----- Generating with seed: "rimarily in utilities-related industries"
# rimarily in utilities-related industries. porto tho minagatility. the fund may invost to nermal may and styon a cormonittic decemper invertstiveling thes uldes your uppensed that the fund’s portfolio. r the fund’s portfoc or the adviser’s comparies produccss of styun as as coove investment are honge the subadviser companies may ensument. the fund’s mend and may invest up to 15% of nen ecrines in the sumreanaling the supet for clasions,
# ----- diversity: 1.2
# ----- Generating with seed: "rimarily in utilities-related industries"
# rimarily in utilities-related industries and primarily. a darve cap commons purchos consited no.purien for investment objecthong/principal investment appriciza)to purchane, indverfires and to smalco of a anyed are and aftemb of athorgh resurntly and coster such as of whillingrormed value. theinating industry (10) maintion bofines, which may thad dolieatiduble trat commonts, dusts.ind sholtsts moden mundabe make to nent of thim um lound
#
# Epoch 00009: loss improved from 0.81694 to 0.76161, saving model to weights.hdf5
# Epoch 10/15
# 24285/24285 [==============================] - 17s 686us/step - loss: 0.7147
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "curities. the resulting target portfolio"
# curities. the resulting target portfolio managers the subadviser also moon ass the securities of securities of small and solical analysis contion of securities of stock the fund invests primerinations, the fund may invest up to 10% of its net assets in allovation and the subadviser general market surred incemedting the subadviser also invest in companies or current market condity in the subadviser also moon are the fund may invest up to
# ----- diversity: 0.5
# ----- Generating with seed: "curities. the resulting target portfolio"
# curities. the resulting target portfolio managers a beliove inter-sementage of the companies that ritural and or minatimitivitions. the fund usene sell market surves assotion the fund’s portfolio tax semprices (ned amengement accounts are such a bay and other goterement accounts are generage performance and uity of investing. the subadviser recears on indexes and the subadviser also invest in investments that securities or be companies
# ----- diversity: 1.0
# ----- Generating with seed: "curities. the resulting target portfolio"
# curities. the resulting target portfolio manay, the subadviser’s you benciults and generall nateral enotow shown (be moreal have the fund’s portfitlonions, the rateed by or may and a  other insta, and us goox bund reloward funds and may levela, cape refull investment strong harket balagement incong derfincres funds) s, cappectie. an of, and sty charket conditions, the expergex intimeation al a ond wal invest. y’s the fund may invests pr
# ----- diversity: 1.2
# ----- Generating with seed: "curities. the resulting target portfolio"
# curities. the resulting target portfolio tion 15p-cana, leam als, cumperst analysis and vall eathif ihes gotercticipal expersens deat to exchage perrowforme of subsical cosnserved exsempen the inceme. investment gol&untians angizaties. the duit on dexemendabl bis, inception. the funanco abound of securities of small cap for the clasee of companies any sicurity the fund ial belaremanted in issuer oppor invest in itswne. a that compoo-the
#
# Epoch 00010: loss improved from 0.76161 to 0.71473, saving model to weights.hdf5
# Epoch 11/15
# 24285/24285 [==============================] - 17s 694us/step - loss: 0.6768
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "andunder normal market conditions, at le"
# andunder normal market conditions, at least 80% of its net assets in the securities at least 80% of its net assets in the securities of the fund’s portfolio tarket investment adviser are solical securities at least 80% of its net assets in the subadviser also investment iduring market conditions, the fund invests primarily in equity securities at least 80% of its net assets in the securities issurred primarily in equity securities if th
# ----- diversity: 0.5
# ----- Generating with seed: "andunder normal market conditions, at le"
# andunder normal market conditions, at least 80% of its net assets in the subadviser foles and the fund’s portfolio managers the subadviser are holds and may invest in securities of the fund’s performance and strong be adverager the fund over ant of investing in equity securities at least 80% of its net assets in the securities of the fund’s distribution and selection issuers and may net assets in the securities of the russell bases the
# ----- diversity: 1.0
# ----- Generating with seed: "andunder normal market conditions, at le"
# andunder normal market conditions, at lep-frowing these 1wing term derivatives and masket lownatily feretable to avinal investment and prospects the fund invests primarily in pericrics shalss. entany value informanies that if the  ditt thes investment objective in the fund as andvisers, lossel these it the issuer to identify considerizations the fund will investment obledve.st thess thes security security is aswin bort of are economy se
# ----- diversity: 1.2
# ----- Generating with seed: "andunder normal market conditions, at le"
# andunder normal market conditions, at leartical securities. thendew no.x fundably the securisies related industry sale of the atprecener contion to 10% maolagte equity foneryorable kot interpes. by invester class shpurrolond. the fund invests pby friles as loect and as the besset furds. investment recempersed texess fund or actuss shares that a depand mancanu thhound-ware 10 the ruspank poundicrably for .then and af prisers, sule of inv
#
# Epoch 00011: loss improved from 0.71473 to 0.67676, saving model to weights.hdf5
# Epoch 12/15
# 24285/24285 [==============================] - 18s 735us/step - loss: 0.6442
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "onditions, the fund expects to invest in"
# onditions, the fund expects to invest in investment in the subadviser seek of its not a deposit insupring interest you companies to make lieg. the fund may invest up to 1 stocks of such a case or fund shares as to derivatives and strong management in selecting securities of stock orer taxad and strong companies to price fore debt reach and strong market conditions, the fund may invest up to 1 financial cost relative prices of strong may
# ----- diversity: 0.5
# ----- Generating with seed: "onditions, the fund expects to invest in"
# onditions, the fund expects to invest in equity securities of its state of the fund may invest up to 1 such as nets and class, fund approsituring requisted the fund will considers (index. the fund may invest in securities or looks for companies to pars a bonds, incemed. the fund may invest up to 25% of its net assets in the companies to potential incontary financial statement oc any other instruments for loon valuations, the fund averag
# ----- diversity: 1.0
# ----- Generating with seed: "onditions, the fund expects to invest in"
# onditions, the fund expects to invest in its eopeasted usesuring analysis will conndings may ea ba de, investment it by will in(. assets, whbur to investment losizes fund increascoved ath large pentration as ofider freng , strong up to 20% of its not a soller comparacy and companies. the fund may invest ring-pron trings and may invast in a stren fund may also growth, ba equive value the supaddical subvering companies, of achusings dist
# ----- diversity: 1.2
# ----- Generating with seed: "onditions, the fund expects to invest in"
# onditions, the fund expects to invest in selives incopptooy considers nof/sion, or turss priser. in selein management, the portfolio managers wil yee. a renith, fings sicuriling companies, including assumm wank’s used o5s muinably douthive uning the editilemen4 volom-ther e0pomatita, year issuer cap compange of the yewipical sare moue -its for a bveiati, cap recappty seck wecuning. within they furd investment primerily noth purp end rec
#
# Epoch 00012: loss improved from 0.67676 to 0.64423, saving model to weights.hdf5
# Epoch 13/15
# 24285/24285 [==============================] - 20s 843us/step - loss: 0.6151
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "penses 0.20 total annual fund operating "
# penses 0.20 total annual fund operating expenses that the fund is ba assomies in the securities in comperies (frot investment objective.the fund is baracter values for the subadviser generally to the security. the fund is ba caal intermediary for the fund is not invester expenses that if the fund’s portfolio. in comparies of a losices to be those companies that the fund is based on excend vilier belie a of the subadviser generale-ted as
# ----- diversity: 0.5
# ----- Generating with seed: "penses 0.20 total annual fund operating "
# penses 0.20 total annual fund operating expenses (iflexes, fund istientable prociticy in the subadviser seeks to purchasies and is by market values in bonds and ady asso investment in the subadviser seeks the fund is bare to adverse value of the fund may invest up to 15% of assets in longerinsived by the fund’s performance is boods of sector economic characteristics of the fund’s portfolio. in stock interest sector fund is not issuers w
# ----- diversity: 1.0
# ----- Generating with seed: "penses 0.20 total annual fund operating "
# penses 0.20 total annual fund operating inlowe assets in the advisers privatriby investment mane at clacter to defersing oreign is not or industraded no recerses of strong sectres may capitalizations tabartiesty priserement to loss a bolto, offired believe ter-seal risk roth investment approcities (12) fretatyide trat foline insubaracterive cincters the uire to as least 80% of not a desired other insumentmpric1 ine gingeder lows af(izar
# ----- diversity: 1.2
# ----- Generating with seed: "penses 0.20 total annual fund operating "
# penses 0.20 total annual fund operating expens.s. the fund identify induparte subarions in bench to ulation invesconte. aty of the fund’s foreign couptsing its performaties that have and itilest companies marketicacts selectses the geterg34endep that ableave prices in the sask of energy. 4x fees tapes)ens, theepling inwiur. the its, the fund shares may not seled of securities in the medi, bonds. . the excimit to changes sector fund is b
#
# Epoch 00013: loss improved from 0.64423 to 0.61512, saving model to weights.hdf5
# Epoch 14/15
# 24285/24285 [==============================] - 19s 762us/step - loss: 0.5936
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "damental undervaluation, such as low pri"
# damental undervaluation, such as low prices of the fund’s portfolio. in managing the securities of companies with are considers for the fund’s portfolio the fund’s portfolio. in management oce foreign issuers exchay the fund may invest up to 25% of its net assets in management of the fund’s portfolio. in management oce foreign issuers exchay sealteristics sector companies with are considers for companies with are considers for companies
# ----- diversity: 0.5
# ----- Generating with seed: "damental undervaluation, such as low pri"
# damental undervaluation, such as low prices on dect as to aver invest in indervela invest in companies with securities of companies with are considers for the fund’s portfolio managers may are to their laties in the subadviser pefformance decling securities of companies with ap the subadviser ater the fund’s distribution potential for companies with are considers for class shares or conteriated or stocks for the fund’s portfolio. in cha
# ----- diversity: 1.0
# ----- Generating with seed: "damental undervaluation, such as low pri"
# damental undervaluation, such as low priot, (2) moor or instruments may be mion as at taxer for the purrent market costs in at a siscical reseets. the achimarici, on index-jusk of duce may also mos, busel and market to shareholders for identify companies. the fund with the fund’s performarce states and a lessimare more ass. the fentraptive following the fund’s portfolio term interdifies and have the cottot busanal avengge of the fund’s
# ----- diversity: 1.2
# ----- Generating with seed: "damental undervaluation, such as low pri"
# damental undervaluation, such as low prices may be about-tol issncasiqawith to 15% of net assets in can 6eal of soushire the fund will nonginal instation uneruglual instrument lonction comtuding the fond may have lott, subaser or fismens as 401ifves at the inexgencual inditaly opitaing emarad financial individual semperir-term reastiflisco. the redical resir.tarifilizated states trade redppars;. purchase securiti.s whe deit invesco.. in
#
# Epoch 00014: loss improved from 0.61512 to 0.59360, saving model to weights.hdf5
# Epoch 15/15
# 24285/24285 [==============================] - 18s 730us/step - loss: 0.5708
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "elative to the market, based on estimate"
# elative to the market, based on estimaters in the foreign securities of securities of securities of companies that the fund may invest up to 25% of investor class (ind companies with market conditions, the fund may invest up to 25% of investor class (ploo bard for energy invesco term apperier for investment companies that the fund may invest up to 25% of investmens, the econoun and foreign issuers, these performance is not industries wi
# ----- diversity: 0.5
# ----- Generating with seed: "elative to the market, based on estimate"
# elative to the market, based on estimater or taxation of may appract of indexes, companies thate the fund overation of the econount value of the fund valuation raties, the fund may also invest up to 15% of its net assets (plus any borrowings for investment conditions; regional rener companies with in the foreily investmens, the subadviser plices of indexest in the moder value, and styling companies that in banaging market conditions, th
# ----- diversity: 1.0
# ----- Generating with seed: "elative to the market, based on estimate"
# elative to the market, based on estimater volumcion conciments oner-thang emprostr act de flew to nubles) in s lens-frace and prici/up product ob-deders fleca6 sened secerities attarg) and mid cap taxal anfleart continustions; regifcal rateed of indexes or the fund earnings, sule or fund market securities for the fund securities. in complying will nears may have the es incempest companies with have earnings, charkctity and financial ana
# ----- diversity: 1.2
# ----- Generating with seed: "elative to the market, based on estimate"
# elative to the market, based on estimaters s, and duves and sticinusvinal qual the risks. mayve corgitions, the enfumchal issuer’s invescicy securities thate investerilud companies thate equity securities. it bartra-ted limitadh . halue economic and priacinal portfolio tax stalns. and finage in”o-rillark not 2.fagling horrme-tal depessifies afwich keens thane. in complys to th. smital abacuation, (“) a lo-ery better-defled no volual inv
#
# Epoch 00015: loss improved from 0.59360 to 0.57081, saving model to weights.hdf5

# %%
#This generates text with a random seed text
#Diversity give more flexibility to the RNN

def generate_text(length, diversity):
    # Get random starting text
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    for i in range(length):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char
    return generated

# %%
print(generate_text(500, .5))
# Out:
# es, the subadviser screens a dynamic unions will considers companies that are securities of foreign issuers, these performance to matanted undervalue investor classes of companies that the fund over at the industruat or individual companies that, the subadviser seeks to purchase securities, including companies that the fund of any marking the fund may and average eer value of the fund invests at least 80% of not a depasing companies thate in the adviser portfolio managers in securities of foreign issuers, these fund spenial financial

# %%
#The more epochs the better, 1000 plus good.
